# %%
import sys
import delivery_driver as dd
sys.path.append("../../deliveryrobot")
from utilities.utilities import *
from kinematics.movementai import *
import time

# %%
start_time = time.time()
robot = dd.DeliveryRobot()
print(f"Robot setup complete in {time.time()-start_time} seconds")

dist = 0.3
# Out:
# Robot setup complete in 0.9199223518371582 seconds

# %%
robot.target_ai.slam_update([0.55,-0.1,0])

goal_time = 1
start_time = time.time()
last_call = time.time()
call_time = 0
i = 0
total_time = 0
while robot.arrive_ai(goal_time, call_time):
    
    # get time it took to make the call
    last_call = time.time()
    call_time = last_call - start_time
    total_time+=call_time
    
    # set a new start time
    start_time = time.time()

    #time.sleep(0.2)
    
    i+=1
    if total_time > 4:
        robot.robot.stop()
        break
        
robot.robot.stop()
robot.robot_ai.kplot.plot_data()
# Out:
# Added data point: time=1721239297.2189898, position=[0.55, -0.1], orientation=0, velocity=None, angular_velocity=None, acceleration=None, angular_acceleration=None
# v_l: 0.0, v_r: 0.0, v: 0.0, omega: 0.0, delta_theta: 0.0
# delta_x 0.0 delta_y 0.0
# distances 0.0 0.0 over 0
# orientation 0.0 over 0
#
# - - - - - - - - - - -
#
# Time since last call: 0
# Steering: [0. 0.] 0.0
# Position: [0. 0.]
# Orientation: 0.0
# Velocity: [0. 0.]
# Rotation Vel: 0.0
# Added data point: time=1721239297.2352314, position=[0. 0.], orientation=0.0, velocity=[0. 0.], angular_velocity=0.0, acceleration=[0. 0.], angular_acceleration=0.0
# target_velocity [ 0.0196774  -0.00357771]
# steering [ 0.00491935 -0.00089443] -0.1
# 0.004919349550499537 > 0.02
# chosen velocities [0.00491935 0.        ]
# omega -0.1
# wheel velocities 0.17302969287714648 -0.01662539153077635
# v_l: 0.16798999308460824, v_r: -0.01662539153077635, v: 0.07568230077691594, omega: -1.5384615384615383, delta_theta: -0.08733602670522836
# delta_x 0.004290904708097151 delta_y -0.00018749447669242278
# distances 0.004290904708097151 -0.00018749447669242278 over 0.05676841735839844
# orientation -0.08733602670522836 over 0.05676841735839844
#
# - - - - - - - - - - -
#
# Time since last call: 0.05676841735839844
# Steering: [ 0.00491935 -0.00089443] -0.1
# Position: [ 0.00579272 -0.00025312]
# Orientation: -0.07939638791384397
# Velocity: [0.00491935 0.        ]
# Rotation Vel: -0.1
# Added data point: time=1721239297.2993317, position=[ 0.00579272 -0.00025312], orientation=-0.07939638791384397, velocity=[0.00491935 0.        ], angular_velocity=-0.1, acceleration=[ 0.00491935 -0.00089443], angular_acceleration=-0.1
# target_velocity [ 0.01967229 -0.0036057 ]
# steering [ 0.00485704 -0.00118709] -0.0018799158860113019
# 0.009776387987324997 > 0.02
# chosen velocities [0.00977639 0.        ]
# omega -0.1
# wheel velocities 0.2499950711837653 0.058098276728076874
# v_l: 0.24271366134346145, v_r: 0.058098276728076874, v: 0.15040596903576917, omega: -1.538461538461538, delta_theta: -0.09488509251521182
# delta_x 0.00919836388990613 delta_y -0.0011730079246346484
# distances 0.00919836388990613 -0.0011730079246346484 over 0.061675310134887695
# orientation -0.09488509251521182 over 0.061675310134887695
#
# - - - - - - - - - - -
#
# Time since last call: 0.061675310134887695
# Steering: [ 0.00485704 -0.00118709] -0.0018799158860113019
# Position: [ 0.01821051 -0.00183668]
# Orientation: -0.16565556292767292
# Velocity: [0.00977639 0.        ]
# Rotation Vel: -0.1
# Added data point: time=1721239297.3449717, position=[ 0.01821051 -0.00183668], orientation=-0.16565556292767292, velocity=[0.00977639 0.        ], angular_velocity=-0.1, acceleration=[ 0.00485704 -0.00118709], angular_acceleration=-0.0018799158860113019
# target_velocity [ 0.01966773 -0.00363048]
# steering [ 0.00469382 -0.0017228 ] 0.08311971180524527
# 0.014470209210203085 > 0.02
# chosen velocities [0.01447021 0.        ]
# omega -0.016880288194754733
# wheel velocities 0.24534641995300033 0.2070367987464277
# v_l: 0.23820040772135953, v_r: 0.2070367987464277, v: 0.2226186032338936, omega: -0.25969674145776533, delta_theta: -0.027159685049164002
# delta_x 0.022908293238209827 delta_y -0.0041505182983501785
# distances 0.022908293238209827 -0.0041505182983501785 over 0.10458230972290039
# orientation -0.027159685049164002 over 0.10458230972290039
#
# - - - - - - - - - - -
#
# Time since last call: 0.10458230972290039
# Steering: [ 0.00469382 -0.0017228 ] 0.08311971180524527
# Position: [ 0.04913671 -0.00743988]
# Orientation: -0.19034618569964018
# Velocity: [0.01447021 0.        ]
# Rotation Vel: -0.016880288194754733
# Added data point: time=1721239297.4586523, position=[ 0.04913671 -0.00743988], orientation=-0.19034618569964018, velocity=[0.01447021 0.        ], angular_velocity=-0.016880288194754733, acceleration=[ 0.00469382 -0.0017228 ], angular_acceleration=0.08311971180524527
# target_velocity [ 0.01966699 -0.00363448]
# steering [ 0.00409737 -0.00286558] 0.024486965170361863
# 0.01856757757652671 > 0.02
# chosen velocities [0.01856758 0.        ]
# omega 0.0076066769756071295
# wheel velocities 0.28699249641123065 0.29267658761635595
# v_l: 0.27863349166138895, v_r: 0.29267658761635595, v: 0.28565503963887245, omega: 0.11702579962472501, delta_theta: 0.005207270636883092
# delta_x 0.012487361828747726 delta_y -0.00237234779820805
# distances 0.012487361828747726 -0.00237234779820805 over 0.044496774673461914
# orientation 0.005207270636883092 over 0.044496774673461914
#
# - - - - - - - - - - -
#
# Time since last call: 0.044496774673461914
# Steering: [ 0.00409737 -0.00286558] 0.024486965170361863
# Position: [ 0.06599465 -0.01064255]
# Orientation: -0.18561230330247372
# Velocity: [0.01856758 0.        ]
# Rotation Vel: 0.0076066769756071295
# Added data point: time=1721239297.4997938, position=[ 0.06599465 -0.01064255], orientation=-0.18561230330247372, velocity=[0.01856758 0.        ], angular_velocity=0.0076066769756071295, acceleration=[ 0.00409737 -0.00286558], angular_acceleration=0.024486965170361863
# target_velocity [ 0.01966762 -0.00363105]
# steering [ 0.00144971 -0.00478522] -0.004559457787343124
# 0.0200172863686126 > 0.02
# chosen velocities [0.02 0.  ]
# omega 0.0030472191882640054
# wheel velocities 0.31429979713594247 0.3107710695370529
# v_l: 0.3051454341125655, v_r: 0.3107710695370529, v: 0.3079582518248092, omega: 0.04688029520406173, delta_theta: 0.0020101962595356223
# delta_x 0.01298067081916232 delta_y -0.0024239237541322073
# distances 0.01298067081916232 -0.0024239237541322073 over 0.042879343032836914
# orientation 0.0020101962595356223 over 0.042879343032836914
#
# - - - - - - - - - - -
#
# Time since last call: 0.042879343032836914
# Steering: [ 0.00144971 -0.00478522] -0.004559457787343124
# Position: [ 0.08351855 -0.01391484]
# Orientation: -0.18378485215744134
# Velocity: [0.02 0.  ]
# Rotation Vel: 0.0030472191882640054
# Added data point: time=1721239297.5406585, position=[ 0.08351855 -0.01391484], orientation=-0.18378485215744134, velocity=[0.02 0.  ], angular_velocity=0.0030472191882640054, acceleration=[ 0.00144971 -0.00478522], angular_acceleration=-0.004559457787343124
# target_velocity [ 0.0196679  -0.00362954]
# steering [-0.00045559 -0.0049792 ] -0.0017507064195214639
# 0.01954441193239185 > 0.02
# chosen velocities [0.01954441 0.        ]
# omega 0.0012965127687425415
# wheel velocities 0.30847107386546635 0.30188004151563697
# v_l: 0.2994864794810353, v_r: 0.30188004151563697, v: 0.30068326049833616, omega: 0.019946350288347257, delta_theta: 0.0008805670621733236
# delta_x 0.013051712879352789 delta_y -0.002420139483568696
# distances 0.013051712879352789 -0.002420139483568696 over 0.04414677619934082
# orientation 0.0008805670621733236 over 0.04414677619934082
#
# - - - - - - - - - - -
#
# Time since last call: 0.04414677619934082
# Steering: [-0.00045559 -0.0049792 ] -0.0017507064195214639
# Position: [ 0.10113836 -0.01718203]
# Orientation: -0.18298433664637467
# Velocity: [0.01954441 0.        ]
# Rotation Vel: 0.0012965127687425415
# Added data point: time=1721239297.5894923, position=[ 0.10113836 -0.01718203], orientation=-0.18298433664637467, velocity=[0.01954441 0.        ], angular_velocity=0.0012965127687425415, acceleration=[-0.00045559 -0.0049792 ], angular_acceleration=-0.0017507064195214639
# target_velocity [ 0.01966803 -0.00362888]
# steering [ 0.00017022 -0.0049971 ] -0.0007668991829077321
# 0.019714631903038193 > 0.02
# chosen velocities [0.01971463 0.        ]
# omega 0.0005296135858348094
# wheel velocities 0.3118975498542269 0.30379090335674275
# v_l: 0.30281315519827856, v_r: 0.30379090335674275, v: 0.30330202927751065, omega: 0.00814790132053489, delta_theta: 0.0003731658707065939
# delta_x 0.013659497313413423 delta_y -0.0025251138558399296
# distances 0.013659497313413423 -0.0025251138558399296 over 0.04579901695251465
# orientation 0.0003731658707065939 over 0.04579901695251465
#
# - - - - - - - - - - -
#
# Time since last call: 0.04579901695251465
# Steering: [ 0.00017022 -0.0049971 ] -0.0007668991829077321
# Position: [ 0.11957869 -0.02059094]
# Orientation: -0.1826450949457323
# Velocity: [0.01971463 0.        ]
# Rotation Vel: 0.0005296135858348094
# Added data point: time=1721239297.6326208, position=[ 0.11957869 -0.02059094], orientation=-0.1826450949457323, velocity=[0.01971463 0.        ], angular_velocity=0.0005296135858348094, acceleration=[ 0.00017022 -0.0049971 ], angular_acceleration=-0.0007668991829077321
# target_velocity [ 0.01966808 -0.00362859]
# steering [-6.41426590e-05 -4.99958856e-03] -0.00032454444234986113
# 0.019650489244017452 > 0.02
# chosen velocities [0.01965049 0.        ]
# omega 0.0002050691434849483
# wheel velocities 0.3111897022810862 0.30250451373271614
# v_l: 0.3021259245447439, v_r: 0.30250451373271614, v: 0.30231521913873005, omega: 0.003154909899768614, delta_theta: 0.00014039309338383977
# delta_x 0.013229393088762474 delta_y -0.0024425553174914814
# distances 0.013229393088762474 -0.0024425553174914814 over 0.044499874114990234
# orientation 0.00014039309338383977 over 0.044499874114990234
#
# - - - - - - - - - - -
#
# Time since last call: 0.044499874114990234
# Steering: [-6.41426590e-05 -4.99958856e-03] -0.00032454444234986113
# Position: [ 0.13743837 -0.02388839]
# Orientation: -0.18251746486083792
# Velocity: [0.01965049 0.        ]
# Rotation Vel: 0.0002050691434849483
# Added data point: time=1721239297.6764967, position=[ 0.13743837 -0.02388839], orientation=-0.18251746486083792, velocity=[0.01965049 0.        ], angular_velocity=0.0002050691434849483, acceleration=[-6.41426590e-05 -4.99958856e-03], angular_acceleration=-0.00032454444234986113
# target_velocity [ 0.0196681  -0.00362848]
# steering [ 2.42667700e-05 -4.99994111e-03] -0.00012179133531375896
# 0.01967475601398693 > 0.02
# chosen velocities [0.01967476 0.        ]
# omega 8.327780817118935e-05
# wheel velocities 0.3116900327055625 0.30276542588426464
# v_l: 0.3026116822384102, v_r: 0.30276542588426464, v: 0.30268855406133743, omega: 0.0012811970487872082, delta_theta: 5.880616451366381e-05
# delta_x 0.013662526357939917 delta_y -0.0025212982903896316
# distances 0.013662526357939917 -0.0025212982903896316 over 0.045899391174316406
# orientation 5.880616451366381e-05 over 0.045899391174316406
#
# - - - - - - - - - - -
#
# Time since last call: 0.045899391174316406
# Steering: [ 2.42667700e-05 -4.99994111e-03] -0.00012179133531375896
# Position: [ 0.15588278 -0.02729214]
# Orientation: -0.18246400471128005
# Velocity: [0.01967476 0.        ]
# Rotation Vel: 8.327780817118935e-05
# Added data point: time=1721239297.7267296, position=[ 0.15588278 -0.02729214], orientation=-0.18246400471128005, velocity=[0.01967476 0.        ], angular_velocity=8.327780817118935e-05, acceleration=[ 2.42667700e-05 -4.99994111e-03], angular_acceleration=-0.00012179133531375896
# target_velocity [ 0.01966811 -0.00362843]
# steering [-9.15977100e-06 -4.99999161e-03] -5.093882380258208e-05
# 0.01966559624298319 > 0.02
# chosen velocities [0.0196656 0.       ]
# omega 3.233898436860727e-05
# wheel velocities 0.3115933166313647 0.3025774858776201
# v_l: 0.30251778313724725, v_r: 0.3025774858776201, v: 0.3025476345074337, omega: 0.0004975228364405745, delta_theta: 2.1726198845495135e-05
# delta_x 0.012992579399645352 delta_y -0.0023971963588978345
# distances 0.012992579399645352 -0.0023971963588978345 over 0.04366874694824219
# orientation 2.1726198845495135e-05 over 0.04366874694824219
#
# - - - - - - - - - - -
#
# Time since last call: 0.04366874694824219
# Steering: [-9.15977100e-06 -4.99999161e-03] -5.093882380258208e-05
# Position: [ 0.17342276 -0.03052835]
# Orientation: -0.1824442536214205
# Velocity: [0.0196656 0.       ]
# Rotation Vel: 3.233898436860727e-05
# Added data point: time=1721239297.7666607, position=[ 0.17342276 -0.03052835], orientation=-0.1824442536214205, velocity=[0.0196656 0.       ], angular_velocity=3.233898436860727e-05, acceleration=[-9.15977100e-06 -4.99999161e-03], angular_acceleration=-5.093882380258208e-05
# target_velocity [ 0.01966811 -0.00362841]
# steering [ 3.46746223e-06 -4.99999880e-03] -1.875079536173274e-05
# 0.019669063705215255 > 0.02
# chosen velocities [0.01966906 0.        ]
# omega 1.358818900687453e-05
# wheel velocities 0.31166609025063213 0.3026135230239333
# v_l: 0.30258843713653605, v_r: 0.3026135230239333, v: 0.30260098008023467, omega: 0.00020904906164372536, delta_theta: 8.856030110875449e-06
# delta_x 0.012606459904877873 delta_y -0.0023257817850203992
# distances 0.012606459904877873 -0.0023257817850203992 over 0.04236340522766113
# orientation 8.856030110875449e-06 over 0.04236340522766113
#
# - - - - - - - - - - -
#
# Time since last call: 0.04236340522766113
# Steering: [ 3.46746223e-06 -4.99999880e-03] -1.875079536173274e-05
# Position: [ 0.19044148 -0.03366816]
# Orientation: -0.18243620268495606
# Velocity: [0.01966906 0.        ]
# Rotation Vel: 1.358818900687453e-05
# Added data point: time=1721239297.8022316, position=[ 0.19044148 -0.03366816], orientation=-0.18243620268495606, velocity=[0.01966906 0.        ], angular_velocity=1.358818900687453e-05, acceleration=[ 3.46746223e-06 -4.99999880e-03], angular_acceleration=-1.875079536173274e-05
# target_velocity [ 0.01966811 -0.0036284 ]
# steering [-1.30858547e-06 -4.99999983e-03] -7.617363666945209e-06
# 0.01966775511974158 > 0.02
# chosen velocities [0.01966776 0.        ]
# omega 5.97082533992932e-06
# wheel velocities 0.31165259655888955 0.30258635952710733
# v_l: 0.3025753364649413, v_r: 0.30258635952710733, v: 0.3025808479960243, omega: 9.18588513837415e-05, delta_theta: 3.824940842739984e-06
# delta_x 0.012390178004912279 delta_y -0.0022858087440003018
# distances 0.012390178004912279 -0.0022858087440003018 over 0.04163932800292969
# orientation 3.824940842739984e-06 over 0.04163932800292969
#
# - - - - - - - - - - -
#
# Time since last call: 0.04163932800292969
# Steering: [-1.30858547e-06 -4.99999983e-03] -7.617363666945209e-06
# Position: [ 0.20716822 -0.036754  ]
# Orientation: -0.1824327254660081
# Velocity: [0.01966776 0.        ]
# Rotation Vel: 5.97082533992932e-06
# Added data point: time=1721239297.852338, position=[ 0.20716822 -0.036754  ], orientation=-0.1824327254660081, velocity=[0.01966776 0.        ], angular_velocity=5.97082533992932e-06, acceleration=[-1.30858547e-06 -4.99999983e-03], angular_acceleration=-7.617363666945209e-06
# target_velocity [ 0.01966811 -0.0036284 ]
# steering [ 4.95659093e-07 -4.99999998e-03] -3.27921175058421e-06
# 0.01966825077883482 > 0.02
# chosen velocities [0.01966825 0.        ]
# omega 2.69161358934511e-06
# wheel velocities 0.3116635686227699 0.3025909580869259
# v_l: 0.3025859889541455, v_r: 0.3025909580869259, v: 0.3025884735205357, omega: 4.140943983636329e-05, delta_theta: 1.8717210869639153e-06
# delta_x 0.013450138499238953 delta_y -0.0024813213556890935
# distances 0.013450138499238953 -0.0024813213556890935 over 0.045200347900390625
# orientation 1.8717210869639153e-06 over 0.045200347900390625
#
# - - - - - - - - - - -
#
# Time since last call: 0.045200347900390625
# Steering: [ 4.95659093e-07 -4.99999998e-03] -3.27921175058421e-06
# Position: [ 0.22532591 -0.04010379]
# Orientation: -0.1824310239013836
# Velocity: [0.01966825 0.        ]
# Rotation Vel: 2.69161358934511e-06
# Added data point: time=1721239297.8978708, position=[ 0.22532591 -0.04010379], orientation=-0.1824310239013836, velocity=[0.01966825 0.        ], angular_velocity=2.69161358934511e-06, acceleration=[ 4.95659093e-07 -4.99999998e-03], angular_acceleration=-3.27921175058421e-06
# target_velocity [ 0.01966812 -0.00362839]
# steering [-1.86877812e-07 -5.00000000e-03] -1.6033712628704677e-06
# 0.01966806390102244 > 0.02
# chosen velocities [0.01966806 0.        ]
# omega 1.0882423264746421e-06
# wheel velocities 0.31166213176426677 0.3025866030086466
# v_l: 0.30258459394589005, v_r: 0.3025866030086466, v: 0.3025855984772683, omega: 1.67421896378935e-05, delta_theta: 7.205964390207199e-07
# delta_x 0.012807394803873386 delta_y -0.0023627311828558943
# distances 0.012807394803873386 -0.0023627311828558943 over 0.04304075241088867
# orientation 7.205964390207199e-07 over 0.04304075241088867
#
# - - - - - - - - - - -
#
# Time since last call: 0.04304075241088867
# Steering: [-1.86877812e-07 -5.00000000e-03] -1.6033712628704677e-06
# Position: [ 0.24261589 -0.04329347]
# Orientation: -0.18243036881371177
# Velocity: [0.01966806 0.        ]
# Rotation Vel: 1.0882423264746421e-06
# Added data point: time=1721239297.9371796, position=[ 0.24261589 -0.04329347], orientation=-0.18243036881371177, velocity=[0.01966806 0.        ], angular_velocity=1.0882423264746421e-06, acceleration=[-1.86877812e-07 -5.00000000e-03], angular_acceleration=-1.6033712628704677e-06
# target_velocity [ 0.01966812 -0.00362839]
# steering [ 7.08482632e-08 -5.00000000e-03] -6.141479080845613e-07
# 0.019668134749285675 > 0.02
# chosen velocities [0.01966813 0.        ]
# omega 4.740944183900808e-07
# wheel velocities 0.3116638383496798 0.30258712607616584
# v_l: 0.30258625082493185, v_r: 0.30258712607616584, v: 0.3025866884505488, omega: 7.293760283244577e-06, delta_theta: 3.119621577293064e-07
# delta_x 0.01272720305226174 delta_y -0.0023479313355369335
# distances 0.01272720305226174 -0.0023479313355369335 over 0.042771100997924805
# orientation 3.119621577293064e-07 over 0.042771100997924805
#
# - - - - - - - - - - -
#
# Time since last call: 0.042771100997924805
# Steering: [ 7.08482632e-08 -5.00000000e-03] -6.141479080845613e-07
# Position: [ 0.25979762 -0.04646318]
# Orientation: -0.1824300852117502
# Velocity: [0.01966813 0.        ]
# Rotation Vel: 4.740944183900808e-07
# Added data point: time=1721239297.9826314, position=[ 0.25979762 -0.04646318], orientation=-0.1824300852117502, velocity=[0.01966813 0.        ], angular_velocity=4.740944183900808e-07, acceleration=[ 7.08482632e-08 -5.00000000e-03], angular_acceleration=-6.141479080845613e-07
# target_velocity [ 0.01966812 -0.00362839]
# steering [-2.66878724e-08 -5.00000000e-03] -2.647596013538589e-07
# 0.019668108061413295 > 0.02
# chosen velocities [0.01966811 0.        ]
# omega 2.0933481703622192e-07
# wheel velocities 0.3116636671748308 0.3025864711000356
# v_l: 0.30258608463575803, v_r: 0.3025864711000356, v: 0.3025862778678968, omega: 3.220535646497602e-06, delta_theta: 1.464492711678714e-07
# delta_x 0.013531348334452445 delta_y -0.002496278307477719
# distances 0.013531348334452445 -0.002496278307477719 over 0.045473575592041016
# orientation 1.464492711678714e-07 over 0.045473575592041016
#
# - - - - - - - - - - -
#
# Time since last call: 0.045473575592041016
# Steering: [-2.66878724e-08 -5.00000000e-03] -2.647596013538589e-07
# Position: [ 0.27806494 -0.04983316]
# Orientation: -0.18242995207604912
# Velocity: [0.01966811 0.        ]
# Rotation Vel: 2.0933481703622192e-07
# Added data point: time=1721239298.028691, position=[ 0.27806494 -0.04983316], orientation=-0.18242995207604912, velocity=[0.01966811 0.        ], angular_velocity=2.0933481703622192e-07, acceleration=[-2.66878724e-08 -5.00000000e-03], angular_acceleration=-2.647596013538589e-07
# target_velocity [ 0.01966812 -0.00362839]
# steering [ 1.01341236e-08 -5.00000000e-03] -1.2402331206473605e-07
# 0.019668118195536925 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 8.531150497148587e-08
# wheel velocities 0.3116639456792619 0.30258651252657265
# v_l: 0.30258635502840964, v_r: 0.30258651252657265, v: 0.30258643377749117, omega: 1.3124846917622612e-06, delta_theta: 5.96164068068931e-08
# delta_x 0.013516173287580042 delta_y -0.0024934775421633667
# distances 0.013516173287580042 -0.0024934775421633667 over 0.04542255401611328
# orientation 5.96164068068931e-08 over 0.04542255401611328
#
# - - - - - - - - - - -
#
# Time since last call: 0.04542255401611328
# Steering: [ 1.01341236e-08 -5.00000000e-03] -1.2402331206473605e-07
# Position: [ 0.29631177 -0.05319935]
# Orientation: -0.18242989787931566
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 8.531150497148587e-08
# Added data point: time=1721239298.0719054, position=[ 0.29631177 -0.05319935], orientation=-0.18242989787931566, velocity=[0.01966812 0.        ], angular_velocity=8.531150497148587e-08, acceleration=[ 1.01341236e-08 -5.00000000e-03], angular_acceleration=-1.2402331206473605e-07
# target_velocity [ 0.01966812 -0.00362839]
# steering [-3.81115551e-09 -5.00000000e-03] -5.024651095197896e-08
# 0.019668114384381416 > 0.02
# chosen velocities [0.01966811 0.        ]
# omega 3.506499401950691e-08
# wheel velocities 0.311663933059942 0.30258640751201626
# v_l: 0.3025863427766427, v_r: 0.30258640751201626, v: 0.3025863751443295, omega: 5.394614463472003e-07, delta_theta: 2.3853811794254972e-08
# delta_x 0.013157685291277723 delta_y -0.0024273429842063404
# distances 0.013157685291277723 -0.0024273429842063404 over 0.044217824935913086
# orientation 2.3853811794254972e-08 over 0.044217824935913086
#
# - - - - - - - - - - -
#
# Time since last call: 0.044217824935913086
# Steering: [-3.81115551e-09 -5.00000000e-03] -5.024651095197896e-08
# Position: [ 0.31407464 -0.05647626]
# Orientation: -0.1824298761940322
# Velocity: [0.01966811 0.        ]
# Rotation Vel: 3.506499401950691e-08
# Added data point: time=1721239298.110271, position=[ 0.31407464 -0.05647626], orientation=-0.1824298761940322, velocity=[0.01966811 0.        ], angular_velocity=3.506499401950691e-08, acceleration=[-3.81115551e-09 -5.00000000e-03], angular_acceleration=-5.024651095197896e-08
# target_velocity [ 0.01966812 -0.00362839]
# steering [ 1.45389532e-09 -5.00000000e-03] -1.9045231614001068e-08
# 0.01966811583827674 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 1.6019762405505844e-08
# wheel velocities 0.3116639742062111 0.30258641229942285
# v_l: 0.3025863827244768, v_r: 0.30258641229942285, v: 0.3025863975119498, omega: 2.4645788373097355e-07, delta_theta: 1.114297885449485e-08
# delta_x 0.013453669166567083 delta_y -0.0024819460848173594
# distances 0.013453669166567083 -0.0024819460848173594 over 0.045212507247924805
# orientation 1.114297885449485e-08 over 0.045212507247924805
#
# - - - - - - - - - - -
#
# Time since last call: 0.045212507247924805
# Steering: [ 1.45389532e-09 -5.00000000e-03] -1.9045231614001068e-08
# Position: [ 0.3322371  -0.05982689]
# Orientation: -0.18242986606405143
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 1.6019762405505844e-08
# Added data point: time=1721239298.1641831, position=[ 0.3322371  -0.05982689], orientation=-0.18242986606405143, velocity=[0.01966812 0.        ], angular_velocity=1.6019762405505844e-08, acceleration=[ 1.45389532e-09 -5.00000000e-03], angular_acceleration=-1.9045231614001068e-08
# target_velocity [ 0.01966812 -0.00362839]
# steering [-5.42921699e-10 -5.00000000e-03] -8.793857197986199e-09
# 0.01966811529535504 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 7.225905207519645e-09
# wheel velocities 0.31166397396391915 0.30258639582937463
# v_l: 0.3025863824892419, v_r: 0.30258639582937463, v: 0.30258638915930824, omega: 1.1116777267246766e-07, delta_theta: 4.756729362906241e-09
# delta_x 0.01273244121346883 delta_y -0.00234889311119412
# distances 0.01273244121346883 -0.00234889311119412 over 0.04278874397277832
# orientation 4.756729362906241e-09 over 0.04278874397277832
#
# - - - - - - - - - - -
#
# Time since last call: 0.04278874397277832
# Steering: [-5.42921699e-10 -5.00000000e-03] -8.793857197986199e-09
# Position: [ 0.34942589 -0.0629979 ]
# Orientation: -0.182429861739752
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 7.225905207519645e-09
# Added data point: time=1721239298.2017734, position=[ 0.34942589 -0.0629979 ], orientation=-0.182429861739752, velocity=[0.01966812 0.        ], angular_velocity=7.225905207519645e-09, acceleration=[-5.42921699e-10 -5.00000000e-03], angular_acceleration=-8.793857197986199e-09
# target_velocity [ 0.01966812 -0.00362839]
# steering [ 2.08331797e-10 -5.00000000e-03] -3.7050540413474664e-09
# 0.019668115503686835 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 3.5208511661721786e-09
# wheel velocities 0.3116639807878283 0.3025863956144293
# v_l: 0.3025863891143964, v_r: 0.3025863956144293, v: 0.30258639236441287, omega: 5.416694084011316e-08, delta_theta: 2.208014577926795e-09
# delta_x 0.012129692015811006 delta_y -0.0022376973000377384
# distances 0.012129692015811006 -0.0022376973000377384 over 0.040763139724731445
# orientation 2.208014577926795e-09 over 0.040763139724731445
#
# - - - - - - - - - - -
#
# Time since last call: 0.040763139724731445
# Steering: [ 2.08331797e-10 -5.00000000e-03] -3.7050540413474664e-09
# Position: [ 0.36580098 -0.06601879]
# Orientation: -0.18242985973246603
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 3.5208511661721786e-09
# Added data point: time=1721239298.239832, position=[ 0.36580098 -0.06601879], orientation=-0.18242985973246603, velocity=[0.01966812 0.        ], angular_velocity=3.5208511661721786e-09, acceleration=[ 2.08331797e-10 -5.00000000e-03], angular_acceleration=-3.7050540413474664e-09
# target_velocity [ 0.01966812 -0.00362839]
# steering [-7.71887058e-11 -5.00000000e-03] -1.69428604479549e-09
# 0.01966811542649813 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 1.8265651213766887e-09
# wheel velocities 0.3116639811755592 0.30258639286295436
# v_l: 0.30258638949083416, v_r: 0.30258639286295436, v: 0.30258639117689423, omega: 2.8101001618245174e-08, delta_theta: 1.316731965789456e-09
# delta_x 0.013943048039576139 delta_y -0.00257222694201558
# distances 0.013943048039576139 -0.00257222694201558 over 0.04685711860656738
# orientation 1.316731965789456e-09 over 0.04685711860656738
#
# - - - - - - - - - - -
#
# Time since last call: 0.04685711860656738
# Steering: [-7.71887058e-11 -5.00000000e-03] -1.69428604479549e-09
# Position: [ 0.38462409 -0.06949129]
# Orientation: -0.18242985853543697
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 1.8265651213766887e-09
# Added data point: time=1721239298.2972205, position=[ 0.38462409 -0.06949129], orientation=-0.18242985853543697, velocity=[0.01966812 0.        ], angular_velocity=1.8265651213766887e-09, acceleration=[-7.71887058e-11 -5.00000000e-03], angular_acceleration=-1.69428604479549e-09
# target_velocity [ 0.01966812 -0.00362839]
# steering [ 3.02184175e-11 -5.00000000e-03] -9.891292229724513e-10
# 0.019668115456716546 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 8.374358984042374e-10
# wheel velocities 0.3116639825948385 0.3025863924148108
# v_l: 0.30258639086877526, v_r: 0.3025863924148108, v: 0.302586391641793, omega: 1.2883629348555322e-08, delta_theta: 6.249643191403669e-10
# delta_x 0.014434413640809149 delta_y -0.002662874523890859
# distances 0.014434413640809149 -0.002662874523890859 over 0.048508405685424805
# orientation 6.249643191403669e-10 over 0.048508405685424805
#
# - - - - - - - - - - -
#
# Time since last call: 0.048508405685424805
# Steering: [ 3.02184175e-11 -5.00000000e-03] -9.891292229724513e-10
# Position: [ 0.40411055 -0.07308617]
# Orientation: -0.18242985796728758
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 8.374358984042374e-10
# Added data point: time=1721239298.342025, position=[ 0.40411055 -0.07308617], orientation=-0.18242985796728758, velocity=[0.01966812 0.        ], angular_velocity=8.374358984042374e-10, acceleration=[ 3.02184175e-11 -5.00000000e-03], angular_acceleration=-9.891292229724513e-10
# target_velocity [ 0.01966812 -0.00362839]
# steering [-1.08638969e-11 -5.00000000e-03] -4.5629278133674234e-10
# 0.01966811544585265 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 3.8114311706749504e-10
# wheel velocities 0.3116639828565167 0.30258639182648056
# v_l: 0.30258639112283175, v_r: 0.30258639182648056, v: 0.30258639147465616, omega: 5.863740049072419e-09, delta_theta: 2.748194760385773e-10
# delta_x 0.013946169641055122 delta_y -0.002572802792610038
# distances 0.013946169641055122 -0.002572802792610038 over 0.04686760902404785
# orientation 2.748194760385773e-10 over 0.04686760902404785
#
# - - - - - - - - - - -
#
# Time since last call: 0.04686760902404785
# Steering: [-1.08638969e-11 -5.00000000e-03] -4.5629278133674234e-10
# Position: [ 0.42293788 -0.07655946]
# Orientation: -0.1824298577174517
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 3.8114311706749504e-10
# Added data point: time=1721239298.3912978, position=[ 0.42293788 -0.07655946], orientation=-0.1824298577174517, velocity=[0.01966812 0.        ], angular_velocity=3.8114311706749504e-10, acceleration=[-1.08638969e-11 -5.00000000e-03], angular_acceleration=-4.5629278133674234e-10
# target_velocity [ 0.01966812 -0.00362839]
# steering [ 4.38914972e-12 -5.00000000e-03] -1.9336043877160591e-10
# 0.0196681154502418 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 1.8778267829588913e-10
# wheel velocities 0.311663983109909 0.3025863917155193
# v_l: 0.3025863913688437, v_r: 0.3025863917155193, v: 0.3025863915421815, omega: 2.888963605377863e-09, delta_theta: 1.3293159747598186e-10
# delta_x 0.013692044392783142 delta_y -0.0025259215187846923
# distances 0.013692044392783142 -0.0025259215187846923 over 0.046013593673706055
# orientation 1.3293159747598186e-10 over 0.046013593673706055
#
# - - - - - - - - - - -
#
# Time since last call: 0.046013593673706055
# Steering: [ 4.38914972e-12 -5.00000000e-03] -1.9336043877160591e-10
# Position: [ 0.44142214 -0.07996945]
# Orientation: -0.1824298575966048
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 1.8778267829588913e-10
# Added data point: time=1721239298.4344807, position=[ 0.44142214 -0.07996945], orientation=-0.1824298575966048, velocity=[0.01966812 0.        ], angular_velocity=1.8778267829588913e-10, acceleration=[ 4.38914972e-12 -5.00000000e-03], angular_acceleration=-1.9336043877160591e-10
# target_velocity [ 0.01966812 -0.00362839]
# steering [-1.49934543e-12 -5.00000000e-03] -8.887868219176198e-11
# 0.019668115448742453 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 9.890399610412715e-11
# wheel velocities 0.31166398317065325 0.3025863916104106
# v_l: 0.3025863914278187, v_r: 0.3025863916104106, v: 0.30258639151911465, omega: 1.521599513054639e-09, delta_theta: 7.969715848563228e-11
# delta_x 0.015585639339416637 delta_y -0.0028752537338787554
# distances 0.015585639339416637 -0.0028752537338787554 over 0.05237722396850586
# orientation 7.969715848563228e-11 over 0.05237722396850586
#
# - - - - - - - - - - -
#
# Time since last call: 0.05237722396850586
# Steering: [-1.49934543e-12 -5.00000000e-03] -8.887868219176198e-11
# Position: [ 0.46246275 -0.08385104]
# Orientation: -0.18242985752415283
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 9.890399610412715e-11
# Added data point: time=1721239298.4892333, position=[ 0.46246275 -0.08385104], orientation=-0.18242985752415283, velocity=[0.01966812 0.        ], angular_velocity=9.890399610412715e-11, acceleration=[-1.49934543e-12 -5.00000000e-03], angular_acceleration=-8.887868219176198e-11
# target_velocity [ 0.01966812 -0.00362839]
# steering [ 6.85648367e-13 -5.00000000e-03] -4.8679726916134314e-11
# 0.019668115449428102 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 5.022426918799283e-11
# wheel velocities 0.3116639832278013 0.30258639157602396
# v_l: 0.30258639148330224, v_r: 0.30258639157602396, v: 0.3025863915296631, omega: 7.726809932625164e-10, delta_theta: 3.5055694315175416e-11
# delta_x 0.013500208914905653 delta_y -0.0024905315226173602
# distances 0.013500208914905653 -0.0024905315226173602 over 0.04536890983581543
# orientation 3.5055694315175416e-11 over 0.04536890983581543
#
# - - - - - - - - - - -
#
# Time since last call: 0.04536890983581543
# Steering: [ 6.85648367e-13 -5.00000000e-03] -4.8679726916134314e-11
# Position: [ 0.48068803 -0.08721326]
# Orientation: -0.18242985749228402
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 5.022426918799283e-11
# Added data point: time=1721239298.5336912, position=[ 0.48068803 -0.08721326], orientation=-0.18242985749228402, velocity=[0.01966812 0.        ], angular_velocity=5.022426918799283e-11, acceleration=[ 6.85648367e-13 -5.00000000e-03], angular_acceleration=-4.8679726916134314e-11
# target_velocity [ 0.01966812 -0.00362839]
# steering [-1.93160721e-13 -5.00000000e-03] -1.866240495473903e-11
# 0.01966811544923494 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 3.15618642332538e-11
# wheel velocities 0.3116639832424841 0.3025863915558254
# v_l: 0.3025863914975574, v_r: 0.3025863915558254, v: 0.3025863915266914, omega: 4.855666794571316e-10, delta_theta: 2.2570499545812784e-11
# delta_x 0.013831664296610854 delta_y -0.0025516787297108095
# distances 0.013831664296610854 -0.0025516787297108095 over 0.04648280143737793
# orientation 2.2570499545812784e-11 over 0.04648280143737793
#
# - - - - - - - - - - -
#
# Time since last call: 0.04648280143737793
# Steering: [-1.93160721e-13 -5.00000000e-03] -1.866240495473903e-11
# Position: [ 0.49936078 -0.09065803]
# Orientation: -0.18242985747176538
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 3.15618642332538e-11
# Added data point: time=1721239298.5760748, position=[ 0.49936078 -0.09065803], orientation=-0.18242985747176538, velocity=[0.01966812 0.        ], angular_velocity=3.15618642332538e-11, acceleration=[-1.93160721e-13 -5.00000000e-03], angular_acceleration=-1.866240495473903e-11
# target_velocity [ 0.01966812 -0.00362839]
# steering [ 1.31213702e-13 -5.00000000e-03] -8.880451929371702e-12
# 0.019668115449366155 > 0.02
# chosen velocities [0.01966812 0.        ]
# omega 2.2681412303882098e-11
# wheel velocities 0.3116639832530066 0.3025863915496467
# v_l: 0.3025863915077734, v_r: 0.3025863915496467, v: 0.30258639152871003, omega: 3.489444844184675e-10, delta_theta: 1.562407567936721e-11
# delta_x 0.013323555682847394 delta_y -0.0024579423637732154
# distances 0.013323555682847394 -0.0024579423637732154 over 0.04477524757385254
# orientation 1.562407567936721e-11 over 0.04477524757385254
#
# - - - - - - - - - - -
#
# Time since last call: 0.04477524757385254
# Steering: [ 1.31213702e-13 -5.00000000e-03] -8.880451929371702e-12
# Position: [ 0.51734758 -0.09397625]
# Orientation: -0.18242985745756168
# Velocity: [0.01966812 0.        ]
# Rotation Vel: 2.2681412303882098e-11
# Added data point: time=1721239298.6178274, position=[ 0.51734758 -0.09397625], orientation=-0.18242985745756168, velocity=[0.01966812 0.        ], angular_velocity=2.2681412303882098e-11, acceleration=[ 1.31213702e-13 -5.00000000e-03], angular_acceleration=-8.880451929371702e-12
# target_velocity [ 0.01306097 -0.0024095 ]
# steering [-0.00469739 -0.00171305] -1.708855279503041e-12
# 0.014970725950200232 > 0.02
# chosen velocities [0.01497073 0.        ]
# omega 2.0972557024379057e-11
# wheel velocities 0.23722842657554052 0.23031886079167052
# v_l: 0.23031886075295196, v_r: 0.23031886079167052, v: 0.23031886077231123, omega: 3.2265463449180726e-10, delta_theta: 2.1685143203925853e-11
# delta_x 0.01522252317425625 delta_y -0.002808265712336401
# distances 0.01522252317425625 -0.002808265712336401 over 0.06720852851867676
# orientation 2.1685143203925853e-11 over 0.06720852851867676
#
# - - - - - - - - - - -
#
# Time since last call: 0.06720852851867676
# Steering: [-0.00469739 -0.00171305] -1.708855279503041e-12
# Position: [ 0.53789799 -0.09776741]
# Orientation: -0.18242985743784793
# Velocity: [0.01497073 0.        ]
# Rotation Vel: 2.0972557024379057e-11
# Added data point: time=1721239298.6986356, position=[ 0.53789799 -0.09776741], orientation=-0.18242985743784793, velocity=[0.01497073 0.        ], angular_velocity=2.0972557024379057e-11, acceleration=[-0.00469739 -0.00171305], angular_acceleration=-1.708855279503041e-12
# target_velocity [ 0.0048408  -0.00089304]
# steering [-0.00498068 -0.00043909] 1.5898837801842092e-11
# 0.009990043125256816 > 0.02
# chosen velocities [0.00999004 0.        ]
# omega 3.687139482622115e-11
# wheel velocities 0.1583037602574749 0.1536929711918323
# v_l: 0.153692971123762, v_r: 0.1536929711918323, v: 0.15369297115779718, omega: 5.672524949762447e-10, delta_theta: 5.389454823685492e-11
# delta_x 0.01436002449446468 delta_y -0.00264915112626395
# distances 0.01436002449446468 -0.00264915112626395 over 0.09500980377197266
# orientation 5.389454823685492e-11 over 0.09500980377197266
#
# - - - - - - - - - - -
#
# Time since last call: 0.09500980377197266
# Steering: [-0.00498068 -0.00043909] 1.5898837801842092e-11
# Position: [ 0.55728402 -0.10134376]
# Orientation: -0.1824298573888529
# Velocity: [0.00999004 0.        ]
# Rotation Vel: 3.687139482622115e-11
# Added data point: time=1721239298.7887356, position=[ 0.55728402 -0.10134376], orientation=-0.1824298573888529, velocity=[0.00999004 0.        ], angular_velocity=3.687139482622115e-11, acceleration=[-0.00498068 -0.00043909], angular_acceleration=1.5898837801842092e-11
# target_velocity [-0.00291361  0.00053751]
# steering [-0.00499567  0.0002081 ] 0.1
# 0.004998708785381539 > 0.02
# chosen velocities [0.00499438 0.0002081 ]
# omega 0.1
# wheel velocities -0.01586661463164639 0.1692109043904852
# v_l: -0.015404480224899408, v_r: 0.1692109043904852, v: 0.0769032120827929, omega: 1.5384615384615383, delta_theta: 0.08309070880596453
# delta_x 0.004111127928266903 delta_y -0.0005830569197459488
# distances 0.004111127928266903 -0.0005830569197459488 over 0.05400896072387695
# orientation 0.08309070880596453 over 0.05400896072387695
#
# - - - - - - - - - - -
#
# Time since last call: 0.05400896072387695
# Steering: [-0.00499567  0.0002081 ] 0.1
# Position: [ 0.56283404 -0.10213089]
# Orientation: -0.10689284938343059
# Velocity: [0.00499438 0.0002081 ]
# Rotation Vel: 0.1
# Added data point: time=1721239298.835571, position=[ 0.56283404 -0.10213089], orientation=-0.10689284938343059, velocity=[0.00499438 0.0002081 ], angular_velocity=0.1, acceleration=[-0.00499567  0.0002081 ], angular_acceleration=0.1
# target_velocity [-0.00513362  0.00085236]
# steering [-0.00498991  0.00031742] 0.1
# 0.000525513507519349 > 0.02
# chosen velocities [0.         0.00052551]
# omega 0.1
# wheel velocities -0.08674955518853954 0.10039251550029768
# v_l: -0.08422286911508693, v_r: 0.10039251550029768, v: 0.008084823192605374, omega: 1.5384615384615385, delta_theta: 0.06519831143892729
# delta_x 0.00034162028271813254 delta_y -2.542703180627809e-05
# distances 0.00034162028271813254 -2.542703180627809e-05 over 0.042378902435302734
# orientation 0.06519831143892729 over 0.042378902435302734
#
# - - - - - - - - - - -
#
# Time since last call: 0.042378902435302734
# Steering: [-0.00498991  0.00031742] 0.1
# Position: [ 0.56329523 -0.10216522]
# Orientation: -0.047621657166223956
# Velocity: [0.         0.00052551]
# Rotation Vel: 0.1
# Added data point: time=1721239298.8749614, position=[ 0.56329523 -0.10216522], orientation=-0.047621657166223956, velocity=[0.         0.00052551], angular_velocity=0.1, acceleration=[-0.00498991  0.00031742], angular_acceleration=0.1
# target_velocity [-0.00531809  0.00086609]
# steering [-0.00498978  0.00031955] 0.1
# 0.0008450612470096821 > 0.02
# chosen velocities [0.         0.00084506]
# omega 0.1
# wheel velocities -0.08168595254738503 0.10530863456937972
# v_l: -0.07930675004600489, v_r: 0.10530863456937972, v: 0.013000942261687416, omega: 1.5384615384615385, delta_theta: 0.06886775677020733
# delta_x 0.0005818091267770259 delta_y -7.67321489740402e-06
# distances 0.0005818091267770259 -7.67321489740402e-06 over 0.044764041900634766
# orientation 0.06886775677020733 over 0.044764041900634766
#
# - - - - - - - - - - -
#
# Time since last call: 0.044764041900634766
# Steering: [-0.00498978  0.00031955] 0.1
# Position: [ 0.56408067 -0.10217558]
# Orientation: 0.014985394443055446
# Velocity: [0.         0.00084506]
# Rotation Vel: 0.1
# Added data point: time=1721239298.9304597, position=[ 0.56408067 -0.10217558], orientation=0.014985394443055446, velocity=[0.         0.00084506], angular_velocity=0.1, acceleration=[-0.00498978  0.00031955], angular_acceleration=0.1
# target_velocity [-0.00563227  0.00087023]
# steering [-4.99995008e-03  2.23432761e-05] 0.1
# 0.000867404523146643 > 0.02
# chosen velocities [0.        0.0008674]
# omega 0.1
# wheel velocities -0.08133189755629167 0.10565237727917912
# v_l: -0.0789630073362055, v_r: 0.10565237727917912, v: 0.01334468497148681, omega: 1.5384615384615385, delta_theta: 0.06659837869497447
# delta_x 0.0005768974532731747 delta_y 2.7876920883082997e-05
# distances 0.0005768974532731747 2.7876920883082997e-05 over 0.0432889461517334
# orientation 0.06659837869497447 over 0.0432889461517334
#
# - - - - - - - - - - -
#
# Time since last call: 0.0432889461517334
# Steering: [-4.99995008e-03  2.23432761e-05] 0.1
# Position: [ 0.56485949 -0.10213794]
# Orientation: 0.07552937507485041
# Velocity: [0.        0.0008674]
# Rotation Vel: 0.1
# Added data point: time=1721239298.9633284, position=[ 0.56485949 -0.10213794], orientation=0.07552937507485041, velocity=[0.        0.0008674], angular_velocity=0.1, acceleration=[-4.99995008e-03  2.23432761e-05], angular_acceleration=0.1
# target_velocity [-0.00594379  0.00085518]
# steering [-4.99998942e-03 -1.02862462e-05] 0.1
# 0.0008571182769819227 > 0.02
# chosen velocities [0.         0.00085712]
# omega 0.1
# wheel velocities -0.08149489499551724 0.10549412733818342
# v_l: -0.07912125727720119, v_r: 0.10549412733818342, v: 0.013186435030491113, omega: 1.5384615384615385, delta_theta: 0.06537070641150841
# delta_x 0.0005569275951545415 delta_y 6.0504129374426315e-05
# distances 0.0005569275951545415 6.0504129374426315e-05 over 0.04249095916748047
# orientation 0.06537070641150841 over 0.04249095916748047
#
# - - - - - - - - - - -
#
# Time since last call: 0.04249095916748047
# Steering: [-4.99998942e-03 -1.02862462e-05] 0.1
# Position: [ 0.56561134 -0.10205626]
# Orientation: 0.1349572899944035
# Velocity: [0.         0.00085712]
# Rotation Vel: 0.1
# Added data point: time=1721239299.0068753, position=[ 0.56561134 -0.10205626], orientation=0.1349572899944035, velocity=[0.         0.00085712], angular_velocity=0.1, acceleration=[-4.99998942e-03 -1.02862462e-05], angular_acceleration=0.1
# target_velocity [-0.00624453  0.0008225 ]
# steering [-4.99992319e-03 -2.77149089e-05] 0.1
# 0.000829403368113657 > 0.02
# chosen velocities [0.        0.0008294]
# omega 0.1
# wheel velocities -0.0819340697052759 0.10506774412482549
# v_l: -0.07954764049055912, v_r: 0.10506774412482549, v: 0.012760051817133182, omega: 1.5384615384615385, delta_theta: 0.06920300997220553
# delta_x 0.0005656280591041578 delta_y 9.683702316616076e-05
# distances 0.0005656280591041578 9.683702316616076e-05 over 0.044981956481933594
# orientation 0.06920300997220553 over 0.044981956481933594
#
# - - - - - - - - - - -
#
# Time since last call: 0.044981956481933594
# Steering: [-4.99992319e-03 -2.77149089e-05] 0.1
# Position: [ 0.56637494 -0.10192553]
# Orientation: 0.1978691172418631
# Velocity: [0.        0.0008294]
# Rotation Vel: 0.1
# Added data point: time=1721239299.0604022, position=[ 0.56637494 -0.10192553], orientation=0.1978691172418631, velocity=[0.        0.0008294], angular_velocity=0.1, acceleration=[-4.99992319e-03 -2.77149089e-05], angular_acceleration=0.1
# target_velocity [-0.00654997  0.00077021]
# steering [-4.99979585e-03 -4.51822717e-05] 0.1
# 0.0007842210964054752 > 0.02
# chosen velocities [0.         0.00078422]
# omega 0.1
# wheel velocities -0.08265003493388245 0.10437263225239193
# v_l: -0.08024275236299268, v_r: 0.10437263225239193, v: 0.012064939944699628, omega: 1.5384615384615385, delta_theta: 0.06839165320763221
# delta_x 0.0005218626374389017 delta_y 0.00012332791944624186
# distances 0.0005218626374389017 0.00012332791944624186 over 0.04445457458496094
# orientation 0.06839165320763221 over 0.04445457458496094
#
# - - - - - - - - - - -
#
# Time since last call: 0.04445457458496094
# Steering: [-4.99979585e-03 -4.51822717e-05] 0.1
# Position: [ 0.56707945 -0.10175904]
# Orientation: 0.26004334743061963
# Velocity: [0.         0.00078422]
# Rotation Vel: 0.1
# Added data point: time=1721239299.0995464, position=[ 0.56707945 -0.10175904], orientation=0.26004334743061963, velocity=[0.         0.00078422], angular_velocity=0.1, acceleration=[-4.99979585e-03 -4.51822717e-05], angular_acceleration=0.1
# target_velocity [-0.00683178  0.00070362]
# steering [-4.99965202e-03 -5.89891319e-05] 0.1
# 0.000725231964514459 > 0.02
# chosen velocities [0.         0.00072523]
# omega 0.1
# wheel velocities -0.08358478579307856 0.1034651071463763
# v_l: -0.08115027746900831, v_r: 0.1034651071463763, v: 0.011157414838683995, omega: 1.5384615384615385, delta_theta: 0.06383859194242038
# delta_x 0.00044330973892500454 delta_y 0.0001332373888497049
# distances 0.00044330973892500454 0.0001332373888497049 over 0.04149508476257324
# orientation 0.06383859194242038 over 0.04149508476257324
#
# - - - - - - - - - - -
#
# Time since last call: 0.04149508476257324
# Steering: [-4.99965202e-03 -5.89891319e-05] 0.1
# Position: [ 0.56767792 -0.10157917]
# Orientation: 0.3180784310146382
# Velocity: [0.         0.00072523]
# Rotation Vel: 0.1
# Added data point: time=1721239299.1435125, position=[ 0.56767792 -0.10157917], orientation=0.3180784310146382, velocity=[0.         0.00072523], angular_velocity=0.1, acceleration=[-4.99965202e-03 -5.89891319e-05], angular_acceleration=0.1
# target_velocity [-0.00707117  0.00063167]
# steering [-4.99956235e-03 -6.61535990e-05] 0.1
# 0.0006590783655483612 > 0.02
# chosen velocities [0.         0.00065908]
# omega 0.1
# wheel velocities -0.08463306589977213 0.10244735946997478
# v_l: -0.08216802514540983, v_r: 0.10244735946997478, v: 0.010139667162282477, omega: 1.5384615384615385, delta_theta: 0.0699131305401142
# delta_x 0.0004322767600366389 delta_y 0.00015928175990762155
# distances 0.0004322767600366389 0.00015928175990762155 over 0.04544353485107422
# orientation 0.0699131305401142 over 0.04544353485107422
#
# - - - - - - - - - - -
#
# Time since last call: 0.04544353485107422
# Steering: [-4.99956235e-03 -6.61535990e-05] 0.1
# Position: [ 0.56826149 -0.10136414]
# Orientation: 0.381635822414742
# Velocity: [0.         0.00065908]
# Rotation Vel: 0.1
# Added data point: time=1721239299.182554, position=[ 0.56826149 -0.10136414], orientation=0.381635822414742, velocity=[0.         0.00065908], angular_velocity=0.1, acceleration=[-4.99956235e-03 -6.61535990e-05], angular_acceleration=0.1
# target_velocity [-0.0073046   0.00054565]
# steering [-4.99939734e-03 -7.76289966e-05] 0.1
# 0.000581449368981148 > 0.02
# chosen velocities [0.         0.00058145]
# omega 0.1
# wheel velocities -0.08586318692229873 0.10125306721509458
# v_l: -0.08336231740029003, v_r: 0.10125306721509458, v: 0.008945374907402277, omega: 1.5384615384615385, delta_theta: 0.07931819328894982
# delta_x 0.00042075798673064523 delta_y 0.00018855284886122467
# distances 0.00042075798673064523 0.00018855284886122467 over 0.05155682563781738
# orientation 0.07931819328894982 over 0.05155682563781738
#
# - - - - - - - - - - -
#
# Time since last call: 0.05155682563781738
# Steering: [-4.99939734e-03 -7.76289966e-05] 0.1
# Position: [ 0.56882951 -0.10110959]
# Orientation: 0.4537432708592418
# Velocity: [0.         0.00058145]
# Rotation Vel: 0.1
# Added data point: time=1721239299.2393954, position=[ 0.56882951 -0.10110959], orientation=0.4537432708592418, velocity=[0.         0.00058145], angular_velocity=0.1, acceleration=[-4.99939734e-03 -7.76289966e-05], angular_acceleration=0.1
# target_velocity [-0.00753181  0.00044384]
# steering [-4.99916564e-03 -9.13392828e-05] 0.1
# 0.0004901100861880039 > 0.02
# chosen velocities [0.         0.00049011]
# omega 0.1
# wheel velocities -0.08731056324963625 0.09984784747981544
# v_l: -0.08476753713556917, v_r: 0.09984784747981544, v: 0.007540155172123135, omega: 1.5384615384615385, delta_theta: 0.0694421621469351
# delta_x 0.00030048108231772925 delta_y 0.00015968081994116397
# distances 0.00030048108231772925 0.00015968081994116397 over 0.04513740539550781
# orientation 0.0694421621469351 over 0.04513740539550781
#
# - - - - - - - - - - -
#
# Time since last call: 0.04513740539550781
# Steering: [-4.99916564e-03 -9.13392828e-05] 0.1
# Position: [ 0.56923516 -0.10089402]
# Orientation: 0.5168725091746373
# Velocity: [0.         0.00049011]
# Rotation Vel: 0.1
# Added data point: time=1721239299.2779465, position=[ 0.56923516 -0.10089402], orientation=0.5168725091746373, velocity=[0.         0.00049011], angular_velocity=0.1, acceleration=[-4.99916564e-03 -9.13392828e-05], angular_acceleration=0.1
# target_velocity [-0.00769407  0.00035761]
# steering [-4.99925874e-03 -8.60933837e-05] 0.1
# 0.00040401670245824743 > 0.02
# chosen velocities [0.         0.00040402]
# omega 0.1
# wheel velocities -0.08867481225335394 0.09852333388397302
# v_l: -0.08609205073141159, v_r: 0.09852333388397302, v: 0.0062156415762807185, omega: 1.5384615384615385, delta_theta: 0.06874524630033053
# delta_x 0.00023655457278767985 delta_y 0.0001454384110220733
# distances 0.00023655457278767985 0.0001454384110220733 over 0.044684410095214844
# orientation 0.06874524630033053 over 0.044684410095214844
#
# - - - - - - - - - - -
#
# Time since last call: 0.044684410095214844
# Steering: [-4.99925874e-03 -8.60933837e-05] 0.1
# Position: [ 0.56955451 -0.10069768]
# Orientation: 0.5793681876294833
# Velocity: [0.         0.00040402]
# ...
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.7300503, position=[ 0.57032159 -0.10000752], orientation=2.527725482952569, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.037203201880821817
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.02418208122253418
# orientation 0.037203201880821817 over 0.02418208122253418
#
# - - - - - - - - - - -
#
# Time since last call: 0.02418208122253418
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.561546575571498
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.7530649, position=[ 0.57032159 -0.10000752], orientation=2.561546575571498, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.044191800631009616
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.02872467041015625
# orientation 0.044191800631009616 over 0.02872467041015625
#
# - - - - - - - - - - -
#
# Time since last call: 0.02872467041015625
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.6017209397815066
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.7679179, position=[ 0.57032159 -0.10000752], orientation=2.6017209397815066, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.0351865474994366
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.02287125587463379
# orientation 0.0351865474994366 over 0.02287125587463379
#
# - - - - - - - - - - -
#
# Time since last call: 0.02287125587463379
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.63370871023554
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.8014064, position=[ 0.57032159 -0.10000752], orientation=2.63370871023554, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.03541286175067608
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.023018360137939453
# orientation 0.03541286175067608 over 0.023018360137939453
#
# - - - - - - - - - - -
#
# Time since last call: 0.023018360137939453
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.665902220917973
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.825952, position=[ 0.57032159 -0.10000752], orientation=2.665902220917973, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.03702823932354267
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.024068355560302734
# orientation 0.03702823932354267 over 0.024068355560302734
#
# - - - - - - - - - - -
#
# Time since last call: 0.024068355560302734
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.699564256666648
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.8514361, position=[ 0.57032159 -0.10000752], orientation=2.699564256666648, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.044104502751277044
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.028667926788330078
# orientation 0.044104502751277044 over 0.028667926788330078
#
# - - - - - - - - - - -
#
# Time since last call: 0.028667926788330078
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.739659259167809
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.8736992, position=[ 0.57032159 -0.10000752], orientation=2.739659259167809, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.04446836618276743
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.028904438018798828
# orientation 0.04446836618276743 over 0.028904438018798828
#
# - - - - - - - - - - -
#
# Time since last call: 0.028904438018798828
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.7800850466066884
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.9019694, position=[ 0.57032159 -0.10000752], orientation=2.7800850466066884, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.04149950467623197
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.02697467803955078
# orientation 0.04149950467623197 over 0.02697467803955078
#
# - - - - - - - - - - -
#
# Time since last call: 0.02697467803955078
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.8178118690396268
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.9321697, position=[ 0.57032159 -0.10000752], orientation=2.8178118690396268, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.03770571488600511
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.02450871467590332
# orientation 0.03770571488600511 over 0.02450871467590332
#
# - - - - - - - - - - -
#
# Time since last call: 0.02450871467590332
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.8520897916632677
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.9570093, position=[ 0.57032159 -0.10000752], orientation=2.8520897916632677, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.03699779510498047
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.024048566818237305
# orientation 0.03699779510498047 over 0.024048566818237305
#
# - - - - - - - - - - -
#
# Time since last call: 0.024048566818237305
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.8857241508496134
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239300.98398, position=[ 0.57032159 -0.10000752], orientation=2.8857241508496134, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.04602945767916166
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.029919147491455078
# orientation 0.04602945767916166 over 0.029919147491455078
#
# - - - - - - - - - - -
#
# Time since last call: 0.029919147491455078
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.927569112376124
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239301.0006883, position=[ 0.57032159 -0.10000752], orientation=2.927569112376124, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.1
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.040450096130371094
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.02629256248474121
# orientation 0.040450096130371094 over 0.02629256248474121
#
# - - - - - - - - - - -
#
# Time since last call: 0.02629256248474121
# Steering: [-4.99999966e-03  1.85049970e-06] 0.1
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.9643419270400977
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239301.029651, position=[ 0.57032159 -0.10000752], orientation=2.9643419270400977, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.1
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.0768806266007532
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.028949150672325723
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.01881694793701172
# orientation 0.028949150672325723 over 0.01881694793701172
#
# - - - - - - - - - - -
#
# Time since last call: 0.01881694793701172
# Steering: [-4.99999966e-03  1.85049970e-06] 0.0768806266007532
# Position: [ 0.57032159 -0.10000752]
# Orientation: 2.990659336742212
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239301.059541, position=[ 0.57032159 -0.10000752], orientation=2.990659336742212, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.0768806266007532
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.050563216898639046
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.04207684443547176
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.02734994888305664
# orientation 0.04207684443547176 over 0.02734994888305664
#
# - - - - - - - - - - -
#
# Time since last call: 0.02734994888305664
# Steering: [-4.99999966e-03  1.85049970e-06] 0.050563216898639046
# Position: [ 0.57032159 -0.10000752]
# Orientation: 3.0289110135017316
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239301.0739245, position=[ 0.57032159 -0.10000752], orientation=3.0289110135017316, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.050563216898639046
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] 0.012311540139119254
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.1
# wheel velocities -0.09507692307692309 0.09230769230769231
# v_l: -0.09230769230769231, v_r: 0.09230769230769231, v: 0.0, omega: 1.5384615384615385, delta_theta: 0.04347507770244892
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.028258800506591797
# orientation 0.04347507770244892 over 0.028258800506591797
#
# - - - - - - - - - - -
#
# Time since last call: 0.028258800506591797
# Steering: [-4.99999966e-03  1.85049970e-06] 0.012311540139119254
# Position: [ 0.57032159 -0.10000752]
# Orientation: 3.068433811413049
# Velocity: [0. 0.]
# Rotation Vel: 0.1
# Added data point: time=1721239301.1016943, position=[ 0.57032159 -0.10000752], orientation=3.068433811413049, velocity=[0. 0.], angular_velocity=0.1, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=0.012311540139119254
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] -0.027211257772198044
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.07278874222780196
# wheel velocities -0.06920529645658709 0.06718960821027872
# v_l: -0.06718960821027872, v_r: 0.06718960821027872, v: 0.0, omega: 1.1198268035046455, delta_theta: 0.051502158694946676
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.04599118232727051
# orientation 0.051502158694946676 over 0.04599118232727051
#
# - - - - - - - - - - -
#
# Time since last call: 0.04599118232727051
# Steering: [-4.99999966e-03  1.85049970e-06] -0.027211257772198044
# Position: [ 0.57032159 -0.10000752]
# Orientation: 3.1152539556811822
# Velocity: [0. 0.]
# Rotation Vel: 0.07278874222780196
# Added data point: time=1721239301.160939, position=[ 0.57032159 -0.10000752], orientation=3.1152539556811822, velocity=[0. 0.], angular_velocity=0.07278874222780196, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=-0.027211257772198044
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] -0.0468201442681333
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.02596859795966866
# wheel velocities -0.024690143906269585 0.023971013501232607
# v_l: -0.023971013501232607, v_r: 0.023971013501232607, v: 0.0, omega: 0.3995168916872101, delta_theta: 0.021442710178414894
# delta_x -0.0 delta_y 0.0
# distances -0.0 0.0 over 0.05367159843444824
# orientation 0.021442710178414894 over 0.05367159843444824
#
# - - - - - - - - - - -
#
# Time since last call: 0.05367159843444824
# Steering: [-4.99999966e-03  1.85049970e-06] -0.0468201442681333
# Position: [ 0.57032159 -0.10000752]
# Orientation: 3.13474732857065
# Velocity: [0. 0.]
# Rotation Vel: 0.02596859795966866
# Added data point: time=1721239301.2104602, position=[ 0.57032159 -0.10000752], orientation=3.13474732857065, velocity=[0. 0.], angular_velocity=0.02596859795966866, acceleration=[-4.99999966e-03  1.85049970e-06], angular_acceleration=-0.0468201442681333
# target_velocity [-8.12863538e-03  3.00840768e-06]
# steering [-4.99999966e-03  1.85049970e-06] -0.019493372889467953
# 0.0 > 0.02
# chosen velocities [0. 0.]
# omega 0.0064752250702007075
# wheel velocities -0.006156444759052365 0.005977130834031422

# %% [markdown]
# #

# %%
robot.robot.stop()

# %%
robot.robot_ai.get_wheel_velocities(0.00000000000001,0,0.029158830642700195)
# Out:
# array([1.53846154e-13, 1.53846154e-13])
